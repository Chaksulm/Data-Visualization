# %%
import pandas as pd
ratings = pd.read_csv('C:/Users/vandan/Desktop/ML-sumit/safari vandan/workspace/final project/population.csv',  usecols=range(9), encoding="ISO-8859-1")

# %% [markdown]
# Load the population dataset

# %%
ratings.head()
# Out:
#    LocID     Location  VarID Variant  Time  MidPeriod   PopMale  PopFemale  \
# 0      4  Afghanistan      2  Medium  1950     1950.5  4099.243   3652.874
# 1      4  Afghanistan      2  Medium  1951     1951.5  4134.477   3705.031
# 2      4  Afghanistan      2  Medium  1952     1952.5  4173.993   3760.979
# 3      4  Afghanistan      2  Medium  1953     1953.5  4217.860   3820.747
# 4      4  Afghanistan      2  Medium  1954     1954.5  4266.104   3884.348
#
#    PopTotal
# 0  7752.118
# 1  7839.510
# 2  7934.980
# 3  8038.596
# 4  8150.447

# %% [markdown]
# Load the net user dataset

# %%
net_user = pd.read_csv('C:/Users/vandan/Desktop/ML-sumit/safari vandan/workspace/final project/net_modified1.csv',  usecols=range(9), encoding="ISO-8859-1")
net_user.head()
# Out:
#   Country Name Country Code                                    Indicator Name  \
# 0        Aruba          ABW  Individuals using the Internet (% of population)
# 1  Afghanistan          AFG  Individuals using the Internet (% of population)
# 2       Angola          AGO  Individuals using the Internet (% of population)
# 3      Albania          ALB  Individuals using the Internet (% of population)
# 4      Andorra          AND  Individuals using the Internet (% of population)
#
#    Indicator Code  1960  1961  1962  1963  1964
# 0  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN
# 1  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN
# 2  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN
# 3  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN
# 4  IT.NET.USER.ZS   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# Use pivot_table to make dataset reusable for total population,Male population and female population.

# %%
user_total = ratings.pivot_table(index=['Time'],columns=['Location'],values='PopTotal')
user_total.head()
# Out:
# Location  Afghanistan      Africa   Albania   Algeria  American Samoa  \
# Time
# 1950         7752.118  228670.019  1263.174  8872.247          18.940
# 1951         7839.510  233277.049  1287.497  9039.910          19.296
# 1952         7934.980  238113.121  1316.089  9216.397          19.540
# 1953         8038.596  243177.791  1348.099  9405.443          19.677
# 1954         8150.447  248471.497  1382.878  9609.505          19.729
#
# Location  Andorra    Angola  Anguilla  Antigua and Barbuda  Argentina  \
# Time
# 1950        6.196  4548.023     5.118               46.303  17150.336
# 1951        6.689  4659.333     5.296               48.365  17507.130
# 1952        7.247  4774.561     5.446               49.999  17866.096
# 1953        7.865  4890.469     5.552               51.262  18224.150
# 1954        8.525  5004.763     5.640               52.208  18579.037
#
# Location    ...      Viet Nam  Wallis and Futuna Islands  Western Africa  \
# Time        ...
# ...

# %%
user_male = ratings.pivot_table(index=['Time'],columns=['Location'],values='PopMale')
user_male.head()
# Out:
# Location  Afghanistan      Africa  Albania   Algeria  American Samoa  Andorra  \
# Time
# 1950         4099.243  113585.519  648.220  4511.598           9.823    2.987
# 1951         4134.477  115868.050  661.102  4585.096           9.978    3.260
# 1952         4173.993  118265.726  676.105  4664.468          10.081    3.579
# 1953         4217.860  120780.202  692.829  4751.840          10.130    3.921
# 1954         4266.104  123412.764  710.949  4848.507          10.129    4.302
#
# Location    Angola  Anguilla  Antigua and Barbuda  Argentina    ...     \
# Time                                                            ...
# 1950      2206.642     2.527               22.846   8826.956    ...
# 1951      2261.024     2.594               24.094   8994.099    ...
# 1952      2317.341     2.642               25.014   9163.313    ...
# 1953      2374.015     2.673               25.638   9332.918    ...
# 1954      2429.923     2.686               26.005   9501.631    ...
#
# ...

# %%
user_female = ratings.pivot_table(index=['Time'],columns=['Location'],values='PopFemale')
user_female.head()
# Out:
# Location  Afghanistan      Africa  Albania   Algeria  American Samoa  Andorra  \
# Time
# 1950         3652.874  115084.487  614.944  4360.652           9.118    3.211
# 1951         3705.031  117408.998  626.391  4454.819           9.314    3.433
# 1952         3760.979  119847.370  639.986  4551.930           9.458    3.672
# 1953         3820.747  122397.606  655.265  4653.608           9.553    3.938
# 1954         3884.348  125058.742  671.930  4760.999           9.596    4.231
#
# Location    Angola  Anguilla  Antigua and Barbuda  Argentina    ...     \
# Time                                                            ...
# 1950      2341.379     2.595               23.452   8323.384    ...
# 1951      2398.305     2.701               24.274   8513.037    ...
# 1952      2457.214     2.797               24.986   8702.787    ...
# 1953      2516.447     2.869               25.621   8891.237    ...
# 1954      2574.851     2.946               26.204   9077.407    ...
#
# ...
